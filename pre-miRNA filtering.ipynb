# %%
string = 'GAUUGCUGCAGUCAUAACAAGAGAAGUGGGUUUUGUCGUGCCUGGUUUGCCUGGCACGAUAUUACGCACAACUAAUGGUGACUUUUUGCAUUUC'

def mfei_calculation(precursor, mfe):
    g_and_c = (precursor.count('G')+precursor.count('C'))/len(precursor)
    return mfe/len(precursor)/g_and_c

mfei_calculation(string,-37.3)
# Out:
# -0.8880952380952382

# %%
file = open('default_miRNAFold.txt')

new_file = []
i = 0
for line in file:
    new_file.append(line.split())

# %%
line = 0
mfe = []
sequences = []
while line < len(new_file):
    try:
        if line%2 == 0:
            mfe.append(new_file[line][2])
            sequences.append(new_file[line+1])
            line +=8
    except:
        break

# %%
import ast
mfe = [ast.literal_eval(i) for i in mfe]

# %%
mfe = [i[0] for i in mfe]
sequences = [i[0] for i in sequences]

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.DataFrame(list(zip(mfe, sequences)), columns =['MFE', 'sequence'])

# %%
df
# Out:
#       MFE  \
# 0   -31.2
# 1   -27.1
# 2   -30.0
# 3   -28.7
# 4   -25.5
# ..    ...
# 514 -15.8
# 515 -17.3
# 516 -22.9
# 517 -19.2
# 518 -21.4
#
#                                                                                                                                sequence
# 0              CUUUCGAUCUCUUGUAGAUCUGUUCUCUAAACGAACUUUAAAAUCUGUGUGGCUGUCACUCGGCUGCAUGCUUAGUGCACUCACGCAGUAUAAUUAAUAACUAAUUACUGUCGUUGACAG
# 1                                               AUCUGUGUGGCUGUCACUCGGCUGCAUGCUUAGUGCACUCACGCAGUAUAAUUAAUAACUAAUUACUGUCGUUGACAGGACACGAGU
# 2    CUAAUUACUGUCGUUGACAGGACACGAGUAACUCGUCUAUCUUCUGCAGGCUGCUUACGGUUUCGUCCGUGUUGCAGCCGAUCAUCAGCACAUCUAGGUUUCGUCCGGGUGUGACCGAAAGGUAAGAUGG
# 3                                      UCUAUCUUCUGCAGGCUGCUUACGGUUUCGUCCGUGUUGCAGCCGAUCAUCAGCACAUCUAGGUUUCGUCCGGGUGUGACCGAAAGGUAAGAUGGA
# 4                                            AGGCUGCUUACGGUUUCGUCCGUGUUGCAGCCGAUCAUCAGCACAUCUAGGUUUCGUCCGGGUGUGACCGAAAGGUAAGAUGGAGAGCCU
# ...

# %%
mfeis = [mfei_calculation(sequences[i], mfe[i]) for i in range(len(mfe))]
df['MFEIS'] = mfeis

# %%
df.head()
# Out:
#     MFE  \
# 0 -31.2
# 1 -27.1
# 2 -30.0
# 3 -28.7
# 4 -25.5
#
#                                                                                                                              sequence  \
# 0            CUUUCGAUCUCUUGUAGAUCUGUUCUCUAAACGAACUUUAAAAUCUGUGUGGCUGUCACUCGGCUGCAUGCUUAGUGCACUCACGCAGUAUAAUUAAUAACUAAUUACUGUCGUUGACAG
# 1                                             AUCUGUGUGGCUGUCACUCGGCUGCAUGCUUAGUGCACUCACGCAGUAUAAUUAAUAACUAAUUACUGUCGUUGACAGGACACGAGU
# 2  CUAAUUACUGUCGUUGACAGGACACGAGUAACUCGUCUAUCUUCUGCAGGCUGCUUACGGUUUCGUCCGUGUUGCAGCCGAUCAUCAGCACAUCUAGGUUUCGUCCGGGUGUGACCGAAAGGUAAGAUGG
# 3                                    UCUAUCUUCUGCAGGCUGCUUACGGUUUCGUCCGUGUUGCAGCCGAUCAUCAGCACAUCUAGGUUUCGUCCGGGUGUGACCGAAAGGUAAGAUGGA
# 4                                          AGGCUGCUUACGGUUUCGUCCGUGUUGCAGCCGAUCAUCAGCACAUCUAGGUUUCGUCCGGGUGUGACCGAAAGGUAAGAUGGAGAGCCU
#
#       MFEIS
# 0 -0.650000
# 1 -0.694872
# 2 -0.454545
# 3 -0.574000
# 4 -0.520408

# %%
#cutoff based on MFEIS value, I took very soft threshold, in biorxiv paper 
#it was suggested to go even more extreme to less than -0.85,
#but I for some reason (I think, cutoff point of 0.85 wasn't well explained for me. 
#I saw reasoning that it makes sense for MFEI of miRNA be higher than other coding 
#and non-coding RNAs as mRNAs (0.66), tRNAs (0.64) and rRNAs (0.59). So it makes sense to have > 0.66 (in absolute terms), but 
#-0.85 seems arbitrary. Anyways, the next tool will filter the ones that are left too, so it is not a big problem.)
filtered = df[df['MFEIS'] < -0.65]

# %%
listik = filtered['sequence'].tolist()

# %%
len(listik)
# Out:
# 351

# %%
for line in range(len(listik)):
    print('>test', line)
    print(listik[line])

# %%
#results from this tool http://bioinformatics.hitsz.edu.cn/iMiRNA-SSF/index.jsp
classes = ['Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA', 'Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA', 'Real pre-miRNA','Real pre-miRNA','Real pre-miRNA', 'Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA', 'Real pre-miRNA', 'Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA', 'Real pre-miRNA', 'Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Real pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Real pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA','Pseudo pre-miRNA']

# %%
filtered['class'] = classes
# Out:
# <ipython-input-62-82005fd9e3bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['class'] = classes

# %%
pd.set_option('display.max_colwidth', 20)
filtered
# Out:
#       MFE             sequence     MFEIS             class
# 1   -27.1  AUCUGUGUGGCUGUCA... -0.694872    Real pre-miRNA
# 6   -35.7  AUGGAGAGCCUUGUCC... -0.661111  Pseudo pre-miRNA
# 7   -48.0  ACGUCCAACUCAGUUU... -0.685714    Real pre-miRNA
# 8   -20.2  GAGGCACGUCAACAUC... -0.673333  Pseudo pre-miRNA
# 10  -27.8  GCACCUCAUGGUCAUG... -0.661905  Pseudo pre-miRNA
# ..    ...                  ...       ...               ...
# 497 -39.4  AGUCCAGAUGACCAAA... -0.656667  Pseudo pre-miRNA
# 504 -45.4  GCAACAGUUCAAGAAA... -0.667647    Real pre-miRNA
# 505 -39.9  UUUGCUGCUGCUUGAC... -0.712500  Pseudo pre-miRNA
# 506 -45.3  AUGUCUGGUAAAGGCC... -0.755000  Pseudo pre-miRNA
# 514 -15.8  AUAUAGUCUACUCUUG... -0.752381  Pseudo pre-miRNA
#
# [351 rows x 4 columns]

# %%
filtered_strict = filtered[filtered['MFEIS'] < -0.85]
filtered_strict = filtered_strict[filtered_strict['class'] == 'Real pre-miRNA']

print('Filtered pre-miRNAs:', len(filtered_strict))
filtered_strict
# Out:
# Filtered pre-miRNAs: 27
#       MFE             sequence     MFEIS           class
# 33  -45.7  CAUUAUUUUGGCAUCU... -0.932653  Real pre-miRNA
# 54  -50.7  UGAACUUGAUGAAAGG... -0.938889  Real pre-miRNA
# 71  -44.6  UUCGCACAAAUGUCUA... -0.910204  Real pre-miRNA
# 102 -50.4  UGCUUAUUACAGAGCA... -0.916364  Real pre-miRNA
# 114 -42.9  AACCUGCUUCAAGAGA... -0.893750  Real pre-miRNA
# 143 -44.9  GGUUCCAUCCAUCUUU... -0.935417  Real pre-miRNA
# 180 -41.3  CUUUUGAAGAAGCUGC... -0.860417  Real pre-miRNA
# 200 -39.2  UUACUGCAAAAUGGUA... -0.911628  Real pre-miRNA
# 259 -45.4  UAGUUUUAAGGAAUUA... -0.873077  Real pre-miRNA
# 263 -39.9  AGCGAUUAUGACUACU... -0.997500  Real pre-miRNA
# 264 -39.8  GAUUAUGACUACUAUC... -0.884444  Real pre-miRNA
# 279 -49.0  UGUCCGCAAUUUACAA... -0.907407  Real pre-miRNA
# 303 -29.6  UCUGCUCGCAUAGUGU... -0.986667  Real pre-miRNA
# 308 -36.8  GGAACUUGUCGGCGUU... -0.897561  Real pre-miRNA
# 312 -41.1  UACUUUGCAUAAUGUC... -0.913333  Real pre-miRNA
# ...

# %%
filtered_strict.to_csv('filtered-pre-mirnas.csv', index=False)
